# %% [markdown]
# # Machine Learning

# %% [markdown]
# In machine learning, we do things like find *similar things* (cluster), *classify*, *predict*, *generate*, and more.
#
# Humans are really good a finding patterns. Even from a young age, they can group together items that are similar. Grouping similar things is an essential step in learning concepts, even before language comes into play. Today we'll learn about finding and grouping similar things, called *clustering*.

# %% [markdown]
# # In Daily Life...

# %% [markdown]
# Machine learning today has taken off thanks to the large amounts of data available, thanks to the internet. One example includes Netflix being able to suggest new shows that you might like.
#
# Let's explore this idea more. The main concept behind it is that you might like things that are similar to what you already like. This has some caveats (we'll talk about it in the Ethics for AI section), but it is behind much of the technology we have around us today.

# %% [markdown]
# # Let's talk about music.

# %% [markdown]
# Imagine that we want to make an AI program that suggests new song that you might like. Let's say you are interested in discovering songs that you like from other countries, or in other languages.
#
# But how do you quantify or measure what you like? Could you even describe it?
#
# Let's explore the Spotify Dataset 2017 songs of 2017 to learn how an algorithm to suggest new songs might work.
#
# Consider this dataset:

# %%
import pandas
data = pandas.read_csv('data/spotify.csv')  # Top 2017 songs of 2017 from kaggle.com
print data

# %% [markdown]
# # 1. Features

# %% [markdown]
# In this dataset of 2017 songs, you will see that, alongside every song title, there are many characteristics or **features** extracted for each song. These features include numerical information like tempo, acousticness, etc.

# %%
print data["tempo"]

# %% [markdown]
# Imagine that you were to search this entire database for a song that you might like. Some features will be useful for finding similar songs. Which features do you think would be most useful? Least useful?

# %% [markdown]
# ## 1.1 What we can do with Features

# %% [markdown]
# ## Finding Clusters of Similar Things

# %% [markdown]
# A machine learning technique called **clustering** can help us:
#
# - visualize our data, and
# - find groups of similar items.
#
# We'll use a dataset to suggest songs that are similar to our favourite song. For the sake of this example, let's say that we like the song "Mask Off" by "Future" and would like to find songs that are similar. Let's just look at 2 features for now.

# %%
import pandas
raw_data = pandas.read_csv('data/spotify.csv')  # Top 2017 songs of 2017 from kaggle.com

# Just get the columns we want
dataset = pandas.DataFrame(raw_data, columns = ['tempo', 'acousticness', 'song_title', 'artist'])

# Let's just get the top 20 songs
dataset = dataset[:20]

# Display the dataset
dataset

# %% [markdown]
# ## I want to find songs with a similar tempo!

# %% [markdown]
# Let's start by thinking about how to find similar songs if you only know one thing about each song, e.g. tempo.
# We'll compare each song to Mask Off.
#
# Let's add a new column that finds the differences in tempo from the top song, Mask Off (tempo=150.062)

# %%
# Add a column tempo_difference. 150.062 refers to Mask Off's tempo
dataset['tempo_difference'] = abs(150.062 - dataset.tempo)
dataset

# %% [markdown]
# ## Let's visualize that

# %%
# Now let's visualize that 
import matplotlib.pyplot as plot

plot.scatter(dataset['tempo_difference'], dataset['song_title'])
plot.xlabel('Difference in Tempo')
plot.show()

# %% [markdown]
# ## Now let's find how different they are in terms of acousticness!

# %%
# Add a new column that finds the differences in acousticness from top song, Mask Off (acousticness=0.01020)

dataset['acoustic_difference'] = abs(0.01020 - dataset.acousticness)
dataset

# %%
# Now let's visualize that with a histogram
import matplotlib.pyplot as plot

plot.scatter(dataset['acoustic_difference'], dataset['song_title'])

plot.xlabel('Difference in Acousticness')
plot.show()

# %% [markdown]
# ## Perceptually Similar Songs

# %% [markdown]
# If we manually look at which song looked the closest over both **tempo** and **acousticness** to Mask Off, we get ________________.
#
#
# Did you make your guess? Let's see if that sounds right!
#
#     https://youtu.be/CGt-rTDkMcM
#
#     https://youtu.be/xvZqHgFz51I

# %% [markdown]
# ## Visualizing The Songs in 2D Space

# %% [markdown]
# We can also visualize the two features simultaneously in a 2D plot, like this.

# %%
# Now let's visualize that by plotting all the original data points
import matplotlib.pyplot as plot
plot.rcParams["figure.figsize"] = 10,10

plot.scatter(dataset['tempo'], dataset['acousticness'])
plot.xlabel('Tempo')
plot.ylabel('Acousticness')

for index, row in dataset.iterrows():
    plot.annotate(unicode(row['song_title'], 'utf-8'), xy=(row['tempo'], row['acousticness']))

# %% [markdown]
# # Calculating Distance in 2D Space

# %% [markdown]
# And now that we plot the songs in 2D space, we can properly calculate the distances in 2D mathematically, using the **Euclidean distance** function.

# %%
import numpy
dataset['euclidean_distance'] = numpy.sqrt( (0.01020 - dataset.acousticness)**2 + (150.062 - dataset.tempo)**2)

# Sort the dataset
sorted_dataset_distance = dataset.sort_values('euclidean_distance')

# Display sorted dataset
sorted_dataset_distance

# %% [markdown]
# # Interesting...

# %% [markdown]
# In the last plot above, it suddenly looks like **I've Seen Footage** is really *close* to Mask Off, and **One Night** is really *far* from Mask Off. But in our calculations of Euclidean distance above, both are ~20 units away from **Mask Off**. Can you guess what's wrong?

# %% [markdown]
# When we calculated the distance, the tempo was on a scale of 100's, while the acousticness was on a scale from 0 to 1. This means that the distance in tempo completely overshadowed the minute differences in acousticness.
#
# So, we need to make them both on the same ___.

# %% [markdown]
# ## Scaling Data

# %% [markdown]
# Also known as *normalizing* or standardizing data, we should scale our data to make our comparisons fair.

# %%
# Scale data to [0,1]
from sklearn.preprocessing import MinMaxScaler

# Scale tempo to [0,1]
tempo_column = dataset[['tempo']].values.astype(float)
tempo_scaler = MinMaxScaler().fit(tempo_column)
tempo_scaled = tempo_scaler.transform(tempo_column)
dataset['tempo_normalized'] = pandas.DataFrame(tempo_scaled)

# Scale acousticness to [0,1] (just in case)
acoustic_column = dataset[['acousticness']].values.astype(float)
acoustic_scaler = MinMaxScaler().fit(acoustic_column)
acousticness_scaled = acoustic_scaler.transform(acoustic_column)
dataset['acoustic_normalized'] = pandas.DataFrame(acousticness_scaled)

dataset
# Out:
#       tempo  acousticness                                         song_title  \
# 0   150.062      0.010200                                           Mask Off
# 1   160.083      0.199000                                            Redbone
# 2    75.044      0.034400                                       Xanny Family
# 3    86.468      0.604000                                     Master Of None
# 4   174.004      0.180000                                     Parallel Lines
# 5    85.023      0.004790                                           Sneakin’
# 6    80.030      0.014500                                        Childs Play
# 7   144.154      0.020200                                    Gyöngyhajú lány
# 8   130.035      0.048100                                  I've Seen Footage
# 9    99.994      0.002080                                     Digital Animal
# 10  111.951      0.057200               Subways - In Flagranti Extended Edit
# 11  104.322      0.091500                         Donme Dolap - Baris K Edit
# 12  127.681      0.253000                                            Cemalim
# 13  130.007      0.366000                                          One Night
# 14  125.011      0.440000                                            Oh lala
# 15   99.988      0.019000                                               Char
# 16  123.922      0.023900                                    World In Motion
# 17  122.415      0.233000                          One Nation Under a Groove
# 18  140.061      0.314000                                            Bouncin
# 19  109.982      0.024200                               C O O L - Radio Edit
# 20  128.049      0.000702         Percolator (Jamie Jones Vault Mix) - mixed
# 21  130.031      0.000240                            House of Jealous Lovers
# 22  139.922      0.118000                                          Imma Ride
# 23  138.022      0.000596                                         Girlfriend
# 24   94.498      0.279000                              If I Gave You My Love
# 25  109.977      0.002190                                   This Ready Flesh
# 26  110.016      0.341000                                       Lose My Mind
# 27  100.040      0.018000                                               Char
# 28  120.021      0.051600                                         Look Alive
# 29  129.004      0.282000                    Please Stop Making Fake Versace
# ..      ...           ...                                                ...
# 70  120.001      0.013200                     They Don't Know - Original Mix
# 71  124.012      0.783000                                             Sabali
# 72  106.446      0.518000                                             Spooky
# 73  107.234      0.054800                                 Pick Up The Pieces
# 74  130.195      0.727000                              Have Love Will Travel
# 75  105.018      0.000313                                            Capitol
# 76   76.270      0.340000                   Uncast Shadow Of A Southern Myth
# 77   84.362      0.470000                   I Shall Be Released - Remastered
# 78   80.015      0.855000                             Words I Don't Remember
# 79   82.925      0.005020                                         To The Top
# 80   81.678      0.555000  Them Changes (feat. Flying Lotus & Kamasi Wash...
# 81  144.053      0.186000            Aquafina (feat. GoldLink & Chaz French)
# 82  154.008      0.024900                                           Hot Blur
# 83  175.880      0.010800                                     Summer Madness
# 84   97.835      0.193000                                        The Payback
# 85  106.034      0.019200                                        I'm In Love
# 86  122.281      0.007760                                 I Need You Tonight
# 87   99.407      0.170000                     Everybody Likes Something Good
# 88  158.859      0.022100                                Dadje Von O Von Non
# 89   92.603      0.039700                                        Sugah Daddy
# 90  128.289      0.021300                       International Players Anthem
# 91  114.047      0.045400                                             Swerve
# 92  127.975      0.006720                                      Look At Wrist
# 93  124.997      0.004880                                      Let It Happen
# 94  128.077      0.004190                               My Way (feat. Monty)
# 95  144.005      0.170000                                               Walk
# 96  116.081      0.060400                 The Magnificent Seven - Remastered
# 97  110.815      0.057100                                               NOBO
# 98  138.034      0.716000                             The Gaudy Side of Town
# 99  134.009      0.015100                                              U Mad
#
#                 artist  tempo_normalized  acoustic_normalized  \
# 0               Future          0.748899             0.011762
# 1     Childish Gambino          0.846361             0.232618
# 2               Future          0.019286             0.040071
# 3          Beach House          0.130394             0.706383
# 4          Junior Boys          0.981754             0.210392
# 5                Drake          0.116340             0.005434
# 6                Drake          0.067779             0.016792
# 7                Omega          0.691438             0.023460
# 8          Death Grips          0.554119             0.056097
# 9          Honey Claws          0.261946             0.002264
# 10      The Avalanches          0.378237             0.066742
# 11  Modern Folk Üçlüsü          0.304039             0.106866
# 12         Erkin Koray          0.531225             0.295787
# 13          Lil Yachty          0.553847             0.427973
# 14                 PNL          0.505257             0.514538
# 15     Crystal Castles          0.261887             0.022056
# 16           New Order          0.494665             0.027788
# 17          Funkadelic          0.480009             0.272391
# 18          Chief Keef          0.651631             0.367144
# 19            Le Youth          0.359087             0.028139
# 20             Cajmere          0.534804             0.000652
# 21         The Rapture          0.554080             0.000111
# 22          Young Thug          0.650279             0.137865
# 23           Ty Segall          0.631800             0.000528
# 24           Myron & E          0.208493             0.326202
# 25               TR/ST          0.359039             0.002392
# 26              A-Trak          0.359418             0.398728
# 27     Crystal Castles          0.262393             0.020887
# 28        Rae Sremmurd          0.456725             0.060191
# 29              Father          0.544092             0.329711
# ..                 ...               ...                  ...
# 70           Disciples          0.456530             0.015272
# 71     Amadou & Mariam          0.495541             0.915775
# 72   Dusty Springfield          0.324697             0.605781
# 73  Average White Band          0.332361             0.063935
# 74          The Sonics          0.555676             0.850267
# 75               TR/ST          0.310808             0.000197
# 76      Parquet Courts          0.031210             0.397559
# 77         Nina Simone          0.109912             0.549631
# 78   How To Dress Well          0.067633             1.000000
# 79         Twin Shadow          0.095936             0.005703
# 80          Thundercat          0.083807             0.649063
# 81             Falcons          0.690456             0.217411
# 82             How Sad          0.787277             0.028958
# 83     Kool & The Gang          1.000000             0.012464
# 84         James Brown          0.240948             0.225600
# 85         Fool's Gold          0.320690             0.022290
# 86      Punkin Machine          0.478705             0.008908
# 87   Ify Jerry Crusade          0.256237             0.198695
# 88       Gnonnas Pédro          0.834457             0.025683
# 89            D'Angelo          0.190062             0.046271
# 90         Swishahouse          0.537138             0.024747
# 91       ILoveMakonnen          0.398623             0.052939
# 92              Father          0.534084             0.007691
# 93         Tame Impala          0.505121             0.005539
# 94           Fetty Wap          0.535076             0.004732
# 95               Kwabs          0.689989             0.198695
# 96           The Clash          0.418405             0.070486
# 97    Tijuana Panthers          0.367189             0.066625
# 98              Gayngs          0.631916             0.837399
# 99           Vic Mensa          0.592770             0.017494
#
#     norm_euclidean_distance
# 0                  0.929496
# 1                  1.096575
# 2                  1.439104
# 3                  1.845443
# 4                  1.041557
# 5                  1.340718
# 6                  1.386281
# 7                  0.967514
# 8                  1.069766
# 9                  1.226443
# 10                 1.188975
# 11                 1.268904
# 12                 1.283471
# 13                 1.388866
# 14                 1.488043
# 15                 1.239721
# 16                 1.083438
# 17                 1.290327
# 18                 1.291938
# 19                 1.174013
# 20                 1.037146
# 21                 1.024860
# 22                 1.087302
# 23                 0.979774
# 24                 1.495910
# 25                 1.155754
# 26                 1.462212
# 27                 1.238560
# 28                 1.132557
# 29                 1.306574
# ..                      ...
# 70                 1.098450
# 71                 1.858292
# 72                 1.655462
# 73                 1.218314
# 74                 1.775549
# 75                 1.188945
# 76                 1.667567
# 77                 1.731318
# 78                 2.125855
# 79                 1.357106
# 80                 1.826112
# 81                 1.139682
# 82                 0.927944
# 83                 0.843976
# 84                 1.398877
# 85                 1.197050
# 86                 1.079148
# 87                 1.368680
# 88                 0.906016
# 89                 1.309494
# 90                 1.054718
# 91                 1.165058
# 92                 1.043118
# 93                 1.059600
# 94                 1.040179
# 95                 1.123002
# 96                 1.165144
# 97                 1.196356
# 98                 1.738032
# 99                 1.015897
#
# [100 rows x 7 columns]

# %%
# Now calculate the distances again using these normalized values
dataset['norm_euclidean_distance'] = numpy.sqrt( (0.011762 - dataset.acoustic_normalized)**2 
                                                + (0.748899 - dataset.tempo_normalized)**2)

# Sort the dataset from closest to farthest
sorted_dataset_distance = dataset.sort_values('norm_euclidean_distance')

# Display sorted dataset
sorted_dataset_distance
# Out:
#       tempo  acousticness                                         song_title  \
# 0   150.062      0.010200                                           Mask Off
# 58  148.040      0.017400                                            Dopeman
# 41  147.028      0.003560                         I Don't Sell Molly No More
# 33  146.923      0.032400                                           Hercules
# 82  154.008      0.024900                                           Hot Blur
# 7   144.154      0.020200                                    Gyöngyhajú lány
# 88  158.859      0.022100                                Dadje Von O Von Non
# 37  142.065      0.056500                                            Jumpman
# 42  139.940      0.001560                                     Versace Python
# 23  138.022      0.000596                                         Girlfriend
# 38  136.024      0.012800                                               7/11
# 30  135.450      0.007910                                         Milly Rock
# 99  134.009      0.015100                                              U Mad
# 22  139.922      0.118000                                          Imma Ride
# 51  132.475      0.063800                                          The Chase
# 21  130.031      0.000240                            House of Jealous Lovers
# 95  144.005      0.170000                                               Walk
# 8   130.035      0.048100                                  I've Seen Footage
# 90  128.289      0.021300                       International Players Anthem
# 81  144.053      0.186000            Aquafina (feat. GoldLink & Chaz French)
# 94  128.077      0.004190                               My Way (feat. Monty)
# 20  128.049      0.000702         Percolator (Jamie Jones Vault Mix) - mixed
# 92  127.975      0.006720                                      Look At Wrist
# 67  127.950      0.007810                                      Look At Wrist
# 31  127.984      0.021900                Blasé (feat. Future & Rae Sremmurd)
# 32  127.029      0.035800                                        Best Friend
# 1   160.083      0.199000                                            Redbone
# 93  124.997      0.004880                                      Let It Happen
# 40  125.008      0.000410                                          Bang That
# 43  124.283      0.002430                                            Monster
# ..      ...           ...                                                ...
# 50   95.995      0.018500                                              Annie
# 87   99.407      0.170000                     Everybody Likes Something Good
# 45   95.487      0.006310              Return Of The Mack - C & J Street Mix
# 26  110.016      0.341000                                       Lose My Mind
# 84   97.835      0.193000                                        The Payback
# 62   92.995      0.000145                                        Fail to Cry
# 14  125.011      0.440000                                            Oh lala
# 89   92.603      0.039700                                        Sugah Daddy
# 24   94.498      0.279000                              If I Gave You My Love
# 44  166.012      0.533000                                             OOOUUU
# 5    85.023      0.004790                                           Sneakin’
# 79   82.925      0.005020                                         To The Top
# 59   81.108      0.000392                                  California Nights
# 6    80.030      0.014500                                        Childs Play
# 72  106.446      0.518000                                             Spooky
# 2    75.044      0.034400                                       Xanny Family
# 61   79.638      0.257000  Ain't No Love In The Heart Of The City - Singl...
# 53   74.749      0.128000                                             Wishes
# 60   92.584      0.435000                                               Baby
# 74                     The Sonics          0.555676             0.850267
# 52                   Leon Bridges          0.024188             0.533254
# 80                     Thundercat          0.083807             0.649063
# 3                     Beach House          0.130394             0.706383
# 71                Amadou & Mariam          0.495541             0.915775
# 78              How To Dress Well          0.067633             1.000000
#
#     norm_euclidean_distance
# 0              5.048807e-07
# 58             2.139384e-02
# 41             3.051372e-02
# 33             4.008101e-02
# 82             4.205416e-02
# 7              5.863934e-02
# 88             8.668276e-02
# 37             9.477798e-02
# 42             9.896273e-02
# 23             1.176371e-01
# 38             1.365655e-01
# 30             1.421395e-01
# 99             1.562344e-01
# 22             1.600877e-01
# 51             1.821786e-01
# 21             1.951666e-01
# 95             1.959952e-01
# 8              1.997616e-01
# 90             2.121587e-01
# 81             2.137923e-01
# 94             2.139383e-01
# 20             2.143832e-01
# 92             2.148534e-01
# 67             2.150761e-01
# 31             2.151631e-01
# 32             2.260083e-01
# 1              2.414051e-01
# 93             2.438578e-01
# 40             2.439403e-01
# 43             2.508873e-01
# ..                      ...
# 50             5.259365e-01
# 87             5.269345e-01
# 45             5.308071e-01
# 26             5.490341e-01
# 84             5.511271e-01
# 62             5.551489e-01
# 14             5.586992e-01
# 89             5.599013e-01
# 24             6.252290e-01
# 44             6.309335e-01
# 5              6.325903e-01
# 79             6.529915e-01
# 59             6.707334e-01
# 6              6.811383e-01
# 72             7.299357e-01
# 2              7.301617e-01
# 61             7.432915e-01
# 53             7.453313e-01
# 60             7.479581e-01
# 65             7.489509e-01
# 64             7.859912e-01
# 76             8.148106e-01
# 98             8.338837e-01
# 77             8.352294e-01
# 74             8.604801e-01
# 52             8.928381e-01
# 80             9.211404e-01
# 3              9.300787e-01
# 71             9.388452e-01
# 78             1.200307e+00
#
# [100 rows x 7 columns]

# %% [markdown]
# Now we can see the closest songs are different! Which are the most similar songs to Mask Off?

# %% [markdown]
# # Visualizing Our Data

# %% [markdown]
# We can start to see our data and notice that there are songs that are similar to Mask Off, but also very different!

# %%
# Now let's visualize that by plotting all the original data points
import matplotlib.pyplot as plot
plot.rcParams["figure.figsize"] = 10,10

plot.scatter(dataset['tempo_normalized'], dataset['acoustic_normalized'])
plot.xlabel('Tempo')
plot.ylabel('Acousticness')

plot.axis('equal')

for index, row in dataset.iterrows():
    plot.annotate(unicode(row['song_title'], 'utf-8'), xy=(row['tempo_normalized'], row['acoustic_normalized']))

# %% [markdown]
# Let's finish by visualizing even more songs from our database.

# %% [markdown]
# # Summary

# %% [markdown]
# Let's put everything together!
#
# **1. Pre-processing**
# - Reading the file
# - Getting the columns (features) we want
# - Choosing the rows (songs) we want
# - Scaling the features to [0,1]
#
# **2. Visualizing Data in Feature Space**
# - Plotting the songs in 2D space
#
# **3. Calculating Differences and Similarities**
# - Calculating distances and sorting them to find the most similar songs

# %%
import pandas
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plot

# Read the data from the spreadsheet
raw_data = pandas.read_csv('data/spotify.csv')  # Top 2017 songs of 2017 from kaggle.com

# Just get the columns we want
dataset = pandas.DataFrame(raw_data, columns = ['tempo', 'acousticness', 'song_title', 'artist'])

# Let's get the top 100 songs
dataset = dataset[:100]

# Scale tempo to [0,1]
tempo_column = dataset[['tempo']].values.astype(float)
tempo_scaler = MinMaxScaler().fit(tempo_column)
tempo_scaled = tempo_scaler.transform(tempo_column)
dataset['tempo_normalized'] = pandas.DataFrame(tempo_scaled)

# Scale acousticness to [0,1] (just in case)
acoustic_column = dataset[['acousticness']].values.astype(float)
acoustic_scaler = MinMaxScaler().fit(acoustic_column)
acousticness_scaled = acoustic_scaler.transform(acoustic_column)
dataset['acoustic_normalized'] = pandas.DataFrame(acousticness_scaled)\

# %%
# Now let's visualize that by plotting all the original data points
plot.rcParams["figure.figsize"] = 20,20

plot.scatter(dataset['tempo_normalized'], dataset['acoustic_normalized'])
plot.xlabel('Tempo')
plot.ylabel('Acousticness')

plot.axis('equal')

for index, row in dataset.iterrows():
    plot.annotate(unicode(row['song_title'], 'utf-8'), xy=(row['tempo_normalized'], row['acoustic_normalized']))

# %%
# Now calculate the distances again using these normalized values
import numpy
dataset['norm_euclidean_distance'] = numpy.sqrt( (0.011762 - dataset.acoustic_normalized)**2 
                                                + (0.748899 - dataset.tempo_normalized)**2)
# Sort the dataset from closest to farthest
sorted_dataset_distance = dataset.sort_values('norm_euclidean_distance')

# Display sorted dataset
sorted_dataset_distance
# Out:
#       tempo  acousticness                                         song_title  \
# 0   150.062      0.010200                                           Mask Off
# 58  148.040      0.017400                                            Dopeman
# 41  147.028      0.003560                         I Don't Sell Molly No More
# 33  146.923      0.032400                                           Hercules
# 82  154.008      0.024900                                           Hot Blur
# 7   144.154      0.020200                                    Gyöngyhajú lány
# 88  158.859      0.022100                                Dadje Von O Von Non
# 37  142.065      0.056500                                            Jumpman
# 42  139.940      0.001560                                     Versace Python
# 23  138.022      0.000596                                         Girlfriend
# 38  136.024      0.012800                                               7/11
# 30  135.450      0.007910                                         Milly Rock
# 99  134.009      0.015100                                              U Mad
# 22  139.922      0.118000                                          Imma Ride
# 51  132.475      0.063800                                          The Chase
# 21  130.031      0.000240                            House of Jealous Lovers
# 95  144.005      0.170000                                               Walk
# 8   130.035      0.048100                                  I've Seen Footage
# 90  128.289      0.021300                       International Players Anthem
# 81  144.053      0.186000            Aquafina (feat. GoldLink & Chaz French)
# 94  128.077      0.004190                               My Way (feat. Monty)
# 20  128.049      0.000702         Percolator (Jamie Jones Vault Mix) - mixed
# 92  127.975      0.006720                                      Look At Wrist
# 67  127.950      0.007810                                      Look At Wrist
# 31  127.984      0.021900                Blasé (feat. Future & Rae Sremmurd)
# 32  127.029      0.035800                                        Best Friend
# 1   160.083      0.199000                                            Redbone
# 93  124.997      0.004880                                      Let It Happen
# 40  125.008      0.000410                                          Bang That
# 43  124.283      0.002430                                            Monster
# ..      ...           ...                                                ...
# 50   95.995      0.018500                                              Annie
# 87   99.407      0.170000                     Everybody Likes Something Good
# 14                            PNL          0.505257             0.514538
# 89                       D'Angelo          0.190062             0.046271
# 24                      Myron & E          0.208493             0.326202
# 44                     Young M.A.          0.904026             0.623328
# 5                           Drake          0.116340             0.005434
# 79                    Twin Shadow          0.095936             0.005703
# 59                     Best Coast          0.078264             0.000289
# 6                           Drake          0.067779             0.016792
# 72              Dusty Springfield          0.324697             0.605781
# 2                          Future          0.019286             0.040071
# 61             Bobby "Blue" Bland          0.063967             0.300466
# 53                    Beach House          0.016417             0.149563
# 60  Ariel Pink's Haunted Graffiti          0.189877             0.508689
# 65                   Sweet Valley          0.000000             0.002942
# 64           Umit Aksu Orkestrasi          0.088087             0.437331
# 76                 Parquet Courts          0.031210             0.397559
# 98                         Gayngs          0.631916             0.837399
# 77                    Nina Simone          0.109912             0.549631
# 74                     The Sonics          0.555676             0.850267
# 52                   Leon Bridges          0.024188             0.533254
# 80                     Thundercat          0.083807             0.649063
# 3                     Beach House          0.130394             0.706383
# 71                Amadou & Mariam          0.495541             0.915775
# 78              How To Dress Well          0.067633             1.000000
#
#     norm_euclidean_distance
# 0              5.048807e-07
# 58             2.139384e-02
# 41             3.051372e-02
# 33             4.008101e-02
# 82             4.205416e-02
# 7              5.863934e-02
# 88             8.668276e-02
# 37             9.477798e-02
# 42             9.896273e-02
# 23             1.176371e-01
# 38             1.365655e-01
# 30             1.421395e-01
# 99             1.562344e-01
# 22             1.600877e-01
# 51             1.821786e-01
# 21             1.951666e-01
# 95             1.959952e-01
# 8              1.997616e-01
# 90             2.121587e-01
# 81             2.137923e-01
# 94             2.139383e-01
# 20             2.143832e-01
# 92             2.148534e-01
# 67             2.150761e-01
# 31             2.151631e-01
# 32             2.260083e-01
# 1              2.414051e-01
# 93             2.438578e-01
# 40             2.439403e-01
# 43             2.508873e-01
# ..                      ...
# 50             5.259365e-01
# 87             5.269345e-01
# 45             5.308071e-01
# 26             5.490341e-01
# 84             5.511271e-01
# 62             5.551489e-01
# 14             5.586992e-01
# 89             5.599013e-01
# 24             6.252290e-01
# 44             6.309335e-01
# 5              6.325903e-01
# 79             6.529915e-01
# 59             6.707334e-01
# 6              6.811383e-01
# 72             7.299357e-01
# 2              7.301617e-01
# 61             7.432915e-01
# 53             7.453313e-01
# 60             7.479581e-01
# 65             7.489509e-01
# 64             7.859912e-01
# 76             8.148106e-01
# 98             8.338837e-01
# 77             8.352294e-01
# 74             8.604801e-01
# 52             8.928381e-01
# 80             9.211404e-01
# 3              9.300787e-01
# 71             9.388452e-01
# 78             1.200307e+00
#
# [100 rows x 7 columns]

# %% [markdown]
# # Your Turn!

# %% [markdown]
# Play with this a little bit -- find a song you like,
# and change the code above to find other songs in the top 100 songs that you might also like!

# %% [markdown]
# What can you say about the songs now that you've visualized it?

# %% [markdown]
# Can you try to add another feature? How would you modify the Euclidean Distance to accomodate another feature

# %% [markdown]
# # Discussion - Ethics and Bias in AI

# %% [markdown]
# What do you think about how features are chosen? Are all features equally important? Who chooses the features to use?
